# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/Happymonk/task2/data.zip" -d "/content/drive/MyDrive/Happymonk/task2/"
# Out:
# Archive:  /content/drive/MyDrive/Happymonk/task2/data.zip
#    creating: /content/drive/MyDrive/Happymonk/task2/data/train/
#    creating: /content/drive/MyDrive/Happymonk/task2/data/train/happy/
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/100.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/103.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/105.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/109.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/111.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/114.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/118.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/119.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/124.jpg
#  extracting: /content/drive/MyDrive/Happymonk/task2/data/train/happy/125.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 9.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 392, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data="/content/drive/MyDrive/Happymonk/task2/data/" epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp "/content/runs/classify/train11/weights/best.pt" "/content/drive/MyDrive/Happymonk/task2/weight_file/"

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/Happymonk/task2/weight_file/best.pt" conf=0.5 source="/content/326.jpg"
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/326.jpg: 640x640 happy 0.49, sad 0.30, neutral 0.22, 4.1ms
# Speed: 11.6ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/Happymonk/task2/weight_file/best.pt" conf=0.5 source="/content/468.jpg"
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/468.jpg: 640x640 neutral 0.90, sad 0.06, happy 0.04, 4.3ms
# Speed: 11.1ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/Happymonk/task2/weight_file/best.pt" conf=0.5 source="/content/611.jpg"
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=classify' model. Ignoring 'task=detect' and updating to 'task=classify' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1438723 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /content/611.jpg: 640x640 sad 0.55, happy 0.36, neutral 0.09, 4.3ms
# Speed: 11.9ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
