# %%
# !nvidia-smi
# Out:
# Tue Nov  7 18:21:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 392, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# !unzip "/content/drive/MyDrive/Happymonk/task1/task1datasetfinal.zip" -d "/content/drive/MyDrive/Happymonk/task1/"
# Out:
# Archive:  /content/drive/MyDrive/Happymonk/task1/task1datasetfinal.zip
#    creating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/
#    creating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/
#   inflating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/image--10-_jpg.rf.ab303c94a06c11ed38f074170edc40b2.jpg
#   inflating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/image--11-_jpg.rf.c37747814e31d282b2ccd9a3f48e3d1f.jpg
#   inflating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/image--12-_jpg.rf.2ac7d8c2e452748059223a352e397de8.jpg
#   inflating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/image--14-_jpg.rf.01c7a241d02c15802c53dcc43fbe7db4.jpg
#   inflating: /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/test/images/image--15-_jpg.rf.cc1682ef8f7d292d745f73fd49d0defa.jpg
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/content/drive/MyDrive/Happymonk/task1/task1datasetfinal/data.yaml" epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp "/content/runs/detect/train2/weights/best.pt"  "/content/drive/MyDrive/Happymonk/task1/weights"

# %%
# !cp -r "/content/runs/detect/train2" "/content/drive/MyDrive/Happymonk/task1"

# %%
# !yolo task=detect mode=val model="/content/runs/detect/train2/weights/best.pt" data="/content/drive/MyDrive/Happymonk/task1/task1datasetfinal/data.yaml"
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Happymonk/task1/task1datasetfinal/val/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100% 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.17it/s]
#                    all         27         60      0.965        0.8      0.942      0.606
# Speed: 9.5ms preprocess, 14.8ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train2/weights/best.pt" conf=0.5 source="/content/The Different Ways People Walk..mp4"
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 97.6ms
# video 1/1 (2/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.8ms
# video 1/1 (3/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.3ms
# video 1/1 (4/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.1ms
# video 1/1 (5/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.8ms
# video 1/1 (6/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.2ms
# video 1/1 (7/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 7.1ms
# video 1/1 (8/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.1ms
# video 1/1 (9/1760) /content/The Different Ways People Walk..mp4: 640x384 1 person, 6.4ms
# ...

# %%
# !unzip "/content/drive/MyDrive/Happymonk/task1/video source.zip" -d "/content/drive/MyDrive/Happymonk/task1"
# Out:
# Archive:  /content/drive/MyDrive/Happymonk/task1/video source.zip
#   inflating: /content/drive/MyDrive/Happymonk/task1/video source/pexels_videos_1721303 (1080p) (1).mp4
#   inflating: /content/drive/MyDrive/Happymonk/task1/video source/pexels_videos_2048206 (1080p) (1).mp4
#   inflating: /content/drive/MyDrive/Happymonk/task1/video source/The Different Ways People Walk. (1).mp4
#   inflating: /content/drive/MyDrive/Happymonk/task1/video source/video_of__man_swimming (720p) (1).mp4
#   inflating: /content/drive/MyDrive/Happymonk/task1/video source/video1.mp4

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train2/weights/best.pt" conf=0.5 source="/content/drive/MyDrive/Happymonk/task1/video_source"
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/3 (1/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 96.9ms
# video 1/3 (2/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 10.8ms
# video 1/3 (3/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 8.3ms
# video 1/3 (4/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 7.5ms
# video 1/3 (5/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 6.5ms
# video 1/3 (6/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 6.5ms
# video 1/3 (7/262) /content/drive/MyDrive/Happymonk/task1/video_source/2_video_source.mp4: 640x384 1 person, 6.3ms
# ...

# %%
# !cp -r "/content/runs/detect/predict4" "/content/drive/MyDrive/Happymonk/task1/video_ouput/"
